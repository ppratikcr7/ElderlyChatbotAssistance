# %%
#=======================================================================
# Important imports
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer
import os
#=======================================================================


#=======================================================================
# Uncomment to train bot on new dataset and replace old database
# Skip if goal is to append to the older database
try:
    os.remove("db.sqlite3")
    print("Old database removed. Training new database")
except:
    print('No database found. Creating new database.')
#=======================================================================


#=======================================================================
# Training the bot
english_bot = ChatBot('Bot')
trainer = ListTrainer(english_bot)
for file in os.listdir('dataset'):
    print('Training using ' + file)
    convData = open('dataset/' + file).readlines()
    trainer.train(convData)
    print("Training completed for " + file)
#=======================================================================
# Out:
# Old database removed. Training new database
# Training using data139.yml
# List Trainer: [####################] 100%
# Training completed for data139.yml
# Training using data105.yml
# List Trainer: [####################] 100%
# Training completed for data105.yml
# Training using data111.yml
# List Trainer: [####################] 100%
# Training completed for data111.yml
# Training using Achalasia - Copy - Copy (14).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (14).yml
# Training using data273.yml
# List Trainer: [####################] 100%
# Training completed for data273.yml
# Training using data267.yml
# List Trainer: [####################] 100%
# Training completed for data267.yml
# Training using Achalasia - Copy - Copy (5).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (5).yml
# Training using data37.yml
# List Trainer: [####################] 100%
# Training completed for data37.yml
# Training using data23.yml
# List Trainer: [####################] 100%
# Training completed for data23.yml
# Training using C. difficile infection.yml
# List Trainer: [####################] 100%
# Training completed for C. difficile infection.yml
# Training using Bone metastasis.yml
# List Trainer: [####################] 100%
# Training completed for Bone metastasis.yml
# Training using Astigmatism.yml
# List Trainer: [####################] 100%
# Training completed for Astigmatism.yml
# Training using Autism spectrum disorder.yml
# List Trainer: [####################] 100%
# Training completed for Autism spectrum disorder.yml
# Training using Achalasia - Copy (17).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (17).yml
# Training using data22.yml
# List Trainer: [####################] 100%
# Training completed for data22.yml
# Training using data36.yml
# List Trainer: [####################] 100%
# Training completed for data36.yml
# Training using data266.yml
# List Trainer: [####################] 100%
# Training completed for data266.yml
# Training using data272.yml
# List Trainer: [####################] 100%
# Training completed for data272.yml
# Training using Arthritis.yml
# List Trainer: [####################] 100%
# Training completed for Arthritis.yml
# Training using Body dysmorphic disorder.yml
# List Trainer: [####################] 100%
# Training completed for Body dysmorphic disorder.yml
# Training using Ankylosing spondylitis.yml
# List Trainer: [####################] 100%
# Training completed for Ankylosing spondylitis.yml
# Training using Achalasia - Copy (6).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (6).yml
# Training using Bunions.yml
# List Trainer: [####################] 100%
# Training completed for Bunions.yml
# Training using Acanthosis nigricans.yml
# List Trainer: [####################] 100%
# Training completed for Acanthosis nigricans.yml
# Training using data110.yml
# List Trainer: [####################] 100%
# Training completed for data110.yml
# Training using data104.yml
# List Trainer: [####################] 100%
# Training completed for data104.yml
# Training using data138.yml
# List Trainer: [####################] 100%
# Training completed for data138.yml
# Training using Carpal tunnel syndrome.yml
# List Trainer: [####################] 100%
# Training completed for Carpal tunnel syndrome.yml
# Training using data112.yml
# List Trainer: [####################] 100%
# Training completed for data112.yml
# Training using data106.yml
# List Trainer: [####################] 100%
# Training completed for data106.yml
# Training using Achalasia - Copy (21).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (21).yml
# Training using Cavernous malformations.yml
# List Trainer: [####################] 100%
# Training completed for Cavernous malformations.yml
# Training using A1 - Copy - Copy - Copy (3).yml
# List Trainer: [####################] 100%
# Training completed for A1 - Copy - Copy - Copy (3).yml
# Training using Achalasia - Copy - Copy (18).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (18).yml
# Training using data258.yml
# List Trainer: [####################] 100%
# Training completed for data258.yml
# Training using Achalasia - Copy - Copy (9).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (9).yml
# Training using data264.yml
# List Trainer: [####################] 100%
# Training completed for data264.yml
# Training using data270.yml
# List Trainer: [####################] 100%
# Training completed for data270.yml
# Training using data20.yml
# List Trainer: [####################] 100%
# Training completed for data20.yml
# Training using data34.yml
# List Trainer: [####################] 100%
# Training completed for data34.yml
# Training using Anthrax.yml
# List Trainer: [####################] 100%
# Training completed for Anthrax.yml
# Training using Achalasia.yml
# List Trainer: [####################] 100%
# Training completed for Achalasia.yml
# Training using Achalasia - Copy - Copy (22).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (22).yml
# Training using data35.yml
# List Trainer: [####################] 100%
# Training completed for data35.yml
# Training using data21.yml
# List Trainer: [####################] 100%
# Training completed for data21.yml
# Training using data271.yml
# List Trainer: [####################] 100%
# Training completed for data271.yml
# Training using data265.yml
# List Trainer: [####################] 100%
# Training completed for data265.yml
# Training using data259.yml
# List Trainer: [####################] 100%
# Training completed for data259.yml
# Training using Carcinoid syndrome.yml
# List Trainer: [####################] 100%
# Training completed for Carcinoid syndrome.yml
# Training using Achilles tendon rupture.yml
# List Trainer: [####################] 100%
# Training completed for Achilles tendon rupture.yml
# Training using data107.yml
# List Trainer: [####################] 100%
# Training completed for data107.yml
# Training using data113.yml
# List Trainer: [####################] 100%
# Training completed for data113.yml
# Training using fracture.yml
# List Trainer: [####################] 100%
# Training completed for fracture.yml
# Training using Bursitis.yml
# List Trainer: [####################] 100%
# Training completed for Bursitis.yml
# Training using data117.yml
# List Trainer: [####################] 100%
# Training completed for data117.yml
# Training using data103.yml
# List Trainer: [####################] 100%
# Training completed for data103.yml
# Training using Chondrosarcoma.yml
# List Trainer: [####################] 100%
# Training completed for Chondrosarcoma.yml
# Training using data261.yml
# List Trainer: [####################] 100%
# Training completed for data261.yml
# Training using data275.yml
# List Trainer: [####################] 100%
# Training completed for data275.yml
# Training using data249.yml
# List Trainer: [####################] 100%
# Training completed for data249.yml
# Training using data19.yml
# List Trainer: [####################] 100%
# Training completed for data19.yml
# Training using Anxiety disorders.yml
# List Trainer: [####################] 100%
# Training completed for Anxiety disorders.yml
# Training using data25.yml
# List Trainer: [####################] 100%
# Training completed for data25.yml
# Training using data31.yml
# List Trainer: [####################] 100%
# Training completed for data31.yml
# Training using Achalasia - Copy - Copy (23).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (23).yml
# Training using data30.yml
# List Trainer: [####################] 100%
# Training completed for data30.yml
# Training using data24.yml
# List Trainer: [####################] 100%
# Training completed for data24.yml
# Training using Carcinoma of unknown primary.yml
# List Trainer: [####################] 100%
# Training completed for Carcinoma of unknown primary.yml
# Training using Arteriovenous fistula.yml
# List Trainer: [####################] 100%
# Training completed for Arteriovenous fistula.yml
# Training using data18.yml
# List Trainer: [####################] 100%
# Training completed for data18.yml
# Training using data248.yml
# List Trainer: [####################] 100%
# Training completed for data248.yml
# Training using Chiari malformation.yml
# List Trainer: [####################] 100%
# Training completed for Chiari malformation.yml
# Training using Achalasia - Copy - Copy (8).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (8).yml
# Training using data274.yml
# List Trainer: [####################] 100%
# Training completed for data274.yml
# Training using data260.yml
# List Trainer: [####################] 100%
# Training completed for data260.yml
# Training using A1 - Copy - Copy - Copy (2).yml
# List Trainer: [####################] 100%
# Training completed for A1 - Copy - Copy - Copy (2).yml
# Training using Achalasia - Copy - Copy (19).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (19).yml
# Training using Anterior cruciate ligament injury.yml
# List Trainer: [####################] 100%
# Training completed for Anterior cruciate ligament injury.yml
# Training using headache.yml
# List Trainer: [####################] 100%
# Training completed for headache.yml
# Training using Achalasia - Copy (20).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (20).yml
# Training using data102.yml
# List Trainer: [####################] 100%
# Training completed for data102.yml
# Training using data116.yml
# List Trainer: [####################] 100%
# Training completed for data116.yml
# Training using data100.yml
# List Trainer: [####################] 100%
# Training completed for data100.yml
# Training using data114.yml
# List Trainer: [####################] 100%
# Training completed for data114.yml
# Training using data128.yml
# List Trainer: [####################] 100%
# Training completed for data128.yml
# Training using Amnestic syndrome.yml
# List Trainer: [####################] 100%
# Training completed for Amnestic syndrome.yml
# Training using Achalasia - Copy (7).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (7).yml
# Training using data276.yml
# List Trainer: [####################] 100%
# Training completed for data276.yml
# Training using Burns.yml
# List Trainer: [####################] 100%
# Training completed for Burns.yml
# Training using data262.yml
# List Trainer: [####################] 100%
# Training completed for data262.yml
# Training using Achalasia - Copy (16).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (16).yml
# Training using data32.yml
# List Trainer: [####################] 100%
# Training completed for data32.yml
# Training using data26.yml
# List Trainer: [####################] 100%
# Training completed for data26.yml
# Training using Angiosarcoma.yml
# List Trainer: [####################] 100%
# Training completed for Angiosarcoma.yml
# Training using Alcoholic hepatitis.yml
# List Trainer: [####################] 100%
# Training completed for Alcoholic hepatitis.yml
# Training using data27.yml
# List Trainer: [####################] 100%
# Training completed for data27.yml
# Training using Achalasia - Copy - Copy (4).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (4).yml
# Training using data33.yml
# List Trainer: [####################] 100%
# Training completed for data33.yml
# Training using data263.yml
# List Trainer: [####################] 100%
# Training completed for data263.yml
# Training using data277.yml
# List Trainer: [####################] 100%
# Training completed for data277.yml
# Training using Achalasia - Copy - Copy (15).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (15).yml
# Training using data129.yml
# List Trainer: [####################] 100%
# Training completed for data129.yml
# Training using data115.yml
# List Trainer: [####################] 100%
# Training completed for data115.yml
# Training using data101.yml
# List Trainer: [####################] 100%
# Training completed for data101.yml
# Training using Aneurysm, abdominal aortic.yml
# List Trainer: [####################] 100%
# Training completed for Aneurysm, abdominal aortic.yml
# Training using Brain tumor.yml
# List Trainer: [####################] 100%
# Training completed for Brain tumor.yml
# Training using data172.yml
# List Trainer: [####################] 100%
# Training completed for data172.yml
# Training using data199.yml
# List Trainer: [####################] 100%
# Training completed for data199.yml
# Training using Achalasia - Copy (27).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (27).yml
# Training using Atrial fibrillation.yml
# List Trainer: [####################] 100%
# Training completed for Atrial fibrillation.yml
# Training using data97.yml
# List Trainer: [####################] 100%
# Training completed for data97.yml
# Training using data238.yml
# List Trainer: [####################] 100%
# Training completed for data238.yml
# Training using data83.yml
# List Trainer: [####################] 100%
# Training completed for data83.yml
# Training using data210.yml
# List Trainer: [####################] 100%
# Training completed for data210.yml
# Training using data204.yml
# List Trainer: [####################] 100%
# Training completed for data204.yml
# Training using Ascariasis.yml
# List Trainer: [####################] 100%
# Training completed for Ascariasis.yml
# Training using data54.yml
# List Trainer: [####################] 100%
# Training completed for data54.yml
# Training using data40.yml
# List Trainer: [####################] 100%
# Training completed for data40.yml
# Training using p3.yml
# List Trainer: [####################] 100%
# Training completed for p3.yml
# Training using data68.yml
# List Trainer: [####################] 100%
# Training completed for data68.yml
# Training using Chronic fatigue syndrome.yml
# List Trainer: [####################] 100%
# Training completed for Chronic fatigue syndrome.yml
# Training using data1.yml
# List Trainer: [####################] 100%
# Training completed for data1.yml
# Training using Adjustment disorders.yml
# List Trainer: [####################] 100%
# Training completed for Adjustment disorders.yml
# Training using Achalasia - Copy - Copy (24).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (24).yml
# Training using data0.yml
# List Trainer: [####################] 100%
# Training completed for data0.yml
# Training using data69.yml
# List Trainer: [####################] 100%
# Training completed for data69.yml
# Training using p2.yml
# List Trainer: [####################] 100%
# Training completed for p2.yml
# Training using Blocked tear duct.yml
# List Trainer: [####################] 100%
# Training completed for Blocked tear duct.yml
# Training using data41.yml
# List Trainer: [####################] 100%
# Training completed for data41.yml
# Training using data55.yml
# List Trainer: [####################] 100%
# Training completed for data55.yml
# Training using data205.yml
# List Trainer: [####################] 100%
# Training completed for data205.yml
# Training using data211.yml
# List Trainer: [####################] 100%
# Training completed for data211.yml
# Training using data82.yml
# List Trainer: [####################] 100%
# Training completed for data82.yml
# Training using data239.yml
# List Trainer: [####################] 100%
# Training completed for data239.yml
# Training using botprofile.yml
# List Trainer: [####################] 100%
# Training completed for botprofile.yml
# Training using data96.yml
# List Trainer: [####################] 100%
# Training completed for data96.yml
# Training using Cellulite.yml
# List Trainer: [####################] 100%
# Training completed for Cellulite.yml
# Training using Blastocystis hominis.yml
# List Trainer: [####################] 100%
# Training completed for Blastocystis hominis.yml
# Training using data198.yml
# List Trainer: [####################] 100%
# Training completed for data198.yml
# Training using Achalasia - Copy - Copy (32).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (32).yml
# Training using data173.yml
# List Trainer: [####################] 100%
# Training completed for data173.yml
# Training using data167.yml
# List Trainer: [####################] 100%
# Training completed for data167.yml
# Training using Brucellosis.yml
# List Trainer: [####################] 100%
# Training completed for Brucellosis.yml
# Training using data159.yml
# List Trainer: [####################] 100%
# Training completed for data159.yml
# Training using data171.yml
# List Trainer: [####################] 100%
# Training completed for data171.yml
# Training using data165.yml
# List Trainer: [####################] 100%
# Training completed for data165.yml
# Training using Balance problems.yml
# List Trainer: [####################] 100%
# Training completed for Balance problems.yml
# Training using Cholera.yml
# List Trainer: [####################] 100%
# Training completed for Cholera.yml
# Training using Cancer.yml
# List Trainer: [####################] 100%
# Training completed for Cancer.yml
# Training using Asbestosis.yml
# List Trainer: [####################] 100%
# Training completed for Asbestosis.yml
# Training using Achalasia - Copy - Copy (12).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (12).yml
# Training using Anemia.yml
# List Trainer: [####################] 100%
# Training completed for Anemia.yml
# Training using data80.yml
# List Trainer: [####################] 100%
# Training completed for data80.yml
# Training using data94.yml
# List Trainer: [####################] 100%
# Training completed for data94.yml
# Training using data207.yml
# List Trainer: [####################] 100%
# Training completed for data207.yml
# Training using data213.yml
# List Trainer: [####################] 100%
# Training completed for data213.yml
# Training using data43.yml
# List Trainer: [####################] 100%
# Training completed for data43.yml
# Training using Achalasia - Copy - Copy (3).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (3).yml
# Training using data57.yml
# List Trainer: [####################] 100%
# Training completed for data57.yml
# Training using data2.yml
# List Trainer: [####################] 100%
# Training completed for data2.yml
# Training using Childhood Apraxia of Speech.yml
# List Trainer: [####################] 100%
# Training completed for Childhood Apraxia of Speech.yml
# Training using Dandruff.yml
# List Trainer: [####################] 100%
# Training completed for Dandruff.yml
# Training using Achalasia - Copy - Copy (28).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (28).yml
# Training using data3.yml
# List Trainer: [####################] 100%
# Training completed for data3.yml
# Training using Cerebral aneurysm.yml
# List Trainer: [####################] 100%
# Training completed for Cerebral aneurysm.yml
# Training using Achalasia - Copy (11).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (11).yml
# Training using Amenorrhea.yml
# List Trainer: [####################] 100%
# Training completed for Amenorrhea.yml
# Training using data56.yml
# List Trainer: [####################] 100%
# Training completed for data56.yml
# Training using P1.yml
# List Trainer: [####################] 100%
# Training completed for P1.yml
# Training using data42.yml
# List Trainer: [####################] 100%
# Training completed for data42.yml
# Training using data212.yml
# List Trainer: [####################] 100%
# Training completed for data212.yml
# Training using data206.yml
# List Trainer: [####################] 100%
# Training completed for data206.yml
# Training using data95.yml
# List Trainer: [####################] 100%
# Training completed for data95.yml
# Training using Angelman syndrome.yml
# List Trainer: [####################] 100%
# Training completed for Angelman syndrome.yml
# Training using data81.yml
# List Trainer: [####################] 100%
# Training completed for data81.yml
# Training using data164.yml
# List Trainer: [####################] 100%
# Training completed for data164.yml
# Training using data170.yml
# List Trainer: [####################] 100%
# Training completed for data170.yml
# Training using data158.yml
# List Trainer: [####################] 100%
# Training completed for data158.yml
# Training using data174.yml
# List Trainer: [####################] 100%
# Training completed for data174.yml
# Training using data160.yml
# List Trainer: [####################] 100%
# Training completed for data160.yml
# Training using data148.yml
# List Trainer: [####################] 100%
# Training completed for data148.yml
# Training using Ataxia.yml
# List Trainer: [####################] 100%
# Training completed for Ataxia.yml
# Training using data202.yml
# List Trainer: [####################] 100%
# Training completed for data202.yml
# Training using data216.yml
# List Trainer: [####################] 100%
# Training completed for data216.yml
# Training using data85.yml
# List Trainer: [####################] 100%
# Training completed for data85.yml
# Training using data91.yml
# List Trainer: [####################] 100%
# Training completed for data91.yml
# Training using Achalasia - Copy (10).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (10).yml
# Training using data46.yml
# List Trainer: [####################] 100%
# Training completed for data46.yml
# Training using p5.yml
# List Trainer: [####################] 100%
# Training completed for p5.yml
# Training using Bacterial vaginosis.yml
# List Trainer: [####################] 100%
# Training completed for Bacterial vaginosis.yml
# Training using data52.yml
# List Trainer: [####################] 100%
# Training completed for data52.yml
# Training using data7.yml
# List Trainer: [####################] 100%
# Training completed for data7.yml
# Training using Achalasia - Copy - Copy (29).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (29).yml
# Training using Cataracts.yml
# List Trainer: [####################] 100%
# Training completed for Cataracts.yml
# Training using Brugada syndrome.yml
# List Trainer: [####################] 100%
# Training completed for Brugada syndrome.yml
# Training using Aspergillosis.yml
# List Trainer: [####################] 100%
# Training completed for Aspergillosis.yml
# Training using data6.yml
# List Trainer: [####################] 100%
# Training completed for data6.yml
# Training using data53.yml
# List Trainer: [####################] 100%
# Training completed for data53.yml
# Training using p4.yml
# List Trainer: [####################] 100%
# Training completed for p4.yml
# Training using data47.yml
# List Trainer: [####################] 100%
# Training completed for data47.yml
# Training using Achalasia - Copy - Copy (2).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (2).yml
# Training using data90.yml
# List Trainer: [####################] 100%
# Training completed for data90.yml
# Training using data84.yml
# List Trainer: [####################] 100%
# Training completed for data84.yml
# Training using data217.yml
# List Trainer: [####################] 100%
# Training completed for data217.yml
# Training using data203.yml
# List Trainer: [####################] 100%
# Training completed for data203.yml
# Training using Achalasia - Copy - Copy (13).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (13).yml
# Training using Allergies.yml
# List Trainer: [####################] 100%
# Training completed for Allergies.yml
# Training using Zollinger-Ellison syndrome.yml
# List Trainer: [####################] 100%
# Training completed for Zollinger-Ellison syndrome.yml
# Training using data149.yml
# List Trainer: [####################] 100%
# Training completed for data149.yml
# Training using data161.yml
# List Trainer: [####################] 100%
# Training completed for data161.yml
# Training using data175.yml
# List Trainer: [####################] 100%
# Training completed for data175.yml
# Training using Achalasia - Copy - Copy (33).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (33).yml
# Training using data163.yml
# List Trainer: [####################] 100%
# Training completed for data163.yml
# Training using data177.yml
# List Trainer: [####################] 100%
# Training completed for data177.yml
# Training using new.yml
# List Trainer: [####################] 100%
# Training completed for new.yml
# Training using data188.yml
# List Trainer: [####################] 100%
# Training completed for data188.yml
# Training using Broken bone.yml
# List Trainer: [####################] 100%
# Training completed for Broken bone.yml
# Training using data215.yml
# List Trainer: [####################] 100%
# Training completed for data215.yml
# Training using Agoraphobia.yml
# List Trainer: [####################] 100%
# Training completed for Agoraphobia.yml
# Training using data201.yml
# List Trainer: [####################] 100%
# Training completed for data201.yml
# Training using data92.yml
# List Trainer: [####################] 100%
# Training completed for data92.yml
# Training using data229.yml
# List Trainer: [####################] 100%
# Training completed for data229.yml
# Training using data86.yml
# List Trainer: [####################] 100%
# Training completed for data86.yml
# Training using data79.yml
# List Trainer: [####################] 100%
# Training completed for data79.yml
# Training using data51.yml
# List Trainer: [####################] 100%
# Training completed for data51.yml
# Training using data45.yml
# List Trainer: [####################] 100%
# Training completed for data45.yml
# Training using p6.yml
# List Trainer: [####################] 100%
# Training completed for p6.yml
# Training using Achalasia - Copy - Copy (25).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (25).yml
# Training using data4.yml
# List Trainer: [####################] 100%
# Training completed for data4.yml
# Training using Arteriovenous malformation.yml
# List Trainer: [####################] 100%
# Training completed for Arteriovenous malformation.yml
# Training using personalinfo.yml
# List Trainer: [####################] 100%
# Training completed for personalinfo.yml
# Training using Cellulitis.yml
# List Trainer: [####################] 100%
# Training completed for Cellulitis.yml
# Training using Achalasia - Copy (30).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (30).yml
# Training using Bladder exstrophy.yml
# List Trainer: [####################] 100%
# Training completed for Bladder exstrophy.yml
# Training using data5.yml
# List Trainer: [####################] 100%
# Training completed for data5.yml
# Training using p7.yml
# List Trainer: [####################] 100%
# Training completed for p7.yml
# Training using data44.yml
# List Trainer: [####################] 100%
# Training completed for data44.yml
# Training using data50.yml
# List Trainer: [####################] 100%
# Training completed for data50.yml
# Training using data78.yml
# List Trainer: [####################] 100%
# Training completed for data78.yml
# Training using Bladder stones.yml
# List Trainer: [####################] 100%
# Training completed for Bladder stones.yml
# Training using data87.yml
# List Trainer: [####################] 100%
# Training completed for data87.yml
# Training using data228.yml
# List Trainer: [####################] 100%
# Training completed for data228.yml
# Training using data93.yml
# List Trainer: [####################] 100%
# Training completed for data93.yml
# Training using data200.yml
# List Trainer: [####################] 100%
# Training completed for data200.yml
# Training using data214.yml
# List Trainer: [####################] 100%
# Training completed for data214.yml
# Training using Paget's disease of bone.yml
# List Trainer: [####################] 100%
# Training completed for Paget's disease of bone.yml
# Training using data189.yml
# List Trainer: [####################] 100%
# Training completed for data189.yml
# Training using Adult Still_s disease.yml
# List Trainer: [####################] 100%
# Training completed for Adult Still_s disease.yml
# Training using Achalasia - Copy (26).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (26).yml
# Training using Asthma.yml
# List Trainer: [####################] 100%
# Training completed for Asthma.yml
# Training using data176.yml
# List Trainer: [####################] 100%
# Training completed for data176.yml
# Training using data162.yml
# List Trainer: [####################] 100%
# Training completed for data162.yml
# Training using Botulism.yml
# List Trainer: [####################] 100%
# Training completed for Botulism.yml
# Training using data147.yml
# List Trainer: [####################] 100%
# Training completed for data147.yml
# Training using data153.yml
# List Trainer: [####################] 100%
# Training completed for data153.yml
# Training using Achalasia - Copy - Copy (30).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (30).yml
# Training using Ambiguous genitalia.yml
# List Trainer: [####################] 100%
# Training completed for Ambiguous genitalia.yml
# Training using data184.yml
# List Trainer: [####################] 100%
# Training completed for data184.yml
# Training using data190.yml
# List Trainer: [####################] 100%
# Training completed for data190.yml
# Training using Ampullary cancer.yml
# List Trainer: [####################] 100%
# Training completed for Ampullary cancer.yml
# Training using data219.yml
# List Trainer: [####################] 100%
# Training completed for data219.yml
# Training using data231.yml
# List Trainer: [####################] 100%
# Training completed for data231.yml
# Training using Paget's disease of the nipple (See_ Paget's disease of the breast).yml
# List Trainer: [####################] 100%
# Training completed for Paget's disease of the nipple (See_ Paget's disease of the breast).yml
# Training using data225.yml
# List Trainer: [####################] 100%
# Training completed for data225.yml
# Training using data75.yml
# List Trainer: [####################] 100%
# Training completed for data75.yml
# Training using data61.yml
# List Trainer: [####################] 100%
# Training completed for data61.yml
# Training using data49.yml
# List Trainer: [####################] 100%
# Training completed for data49.yml
# Training using Zoster.yml
# List Trainer: [####################] 100%
# Training completed for Zoster.yml
# Training using Achalasia - Copy - Copy (26).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (26).yml
# Training using data8.yml
# List Trainer: [####################] 100%
# Training completed for data8.yml
# Training using data9.yml
# List Trainer: [####################] 100%
# Training completed for data9.yml
# Training using data48.yml
# List Trainer: [####################] 100%
# Training completed for data48.yml
# Training using data60.yml
# List Trainer: [####################] 100%
# Training completed for data60.yml
# Training using data74.yml
# List Trainer: [####################] 100%
# Training completed for data74.yml
# Training using data224.yml
# List Trainer: [####################] 100%
# Training completed for data224.yml
# Training using data230.yml
# List Trainer: [####################] 100%
# Training completed for data230.yml
# Training using data218.yml
# List Trainer: [####################] 100%
# Training completed for data218.yml
# Training using Cardiomyopathy.yml
# List Trainer: [####################] 100%
# Training completed for Cardiomyopathy.yml
# Training using Achalasia - Copy (25).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (25).yml
# Training using data191.yml
# List Trainer: [####################] 100%
# Training completed for data191.yml
# Training using data185.yml
# List Trainer: [####################] 100%
# Training completed for data185.yml
# Training using data152.yml
# List Trainer: [####################] 100%
# Training completed for data152.yml
# Training using Brachial plexus injury.yml
# List Trainer: [####################] 100%
# Training completed for Brachial plexus injury.yml
# Training using data146.yml
# List Trainer: [####################] 100%
# Training completed for data146.yml
# Training using Barrett_s esophagus.yml
# List Trainer: [####################] 100%
# Training completed for Barrett_s esophagus.yml
# Training using data178.yml
# List Trainer: [####################] 100%
# Training completed for data178.yml
# Training using data150.yml
# List Trainer: [####################] 100%
# Training completed for data150.yml
# Training using data144.yml
# List Trainer: [####################] 100%
# Training completed for data144.yml
# Training using data193.yml
# List Trainer: [####################] 100%
# Training completed for data193.yml
# Training using Back pain.yml
# List Trainer: [####################] 100%
# Training completed for Back pain.yml
# Training using data187.yml
# List Trainer: [####################] 100%
# Training completed for data187.yml
# Training using disease_Y.yml
# List Trainer: [####################] 100%
# Training completed for disease_Y.yml
# Training using Bedbugs.yml
# List Trainer: [####################] 100%
# Training completed for Bedbugs.yml
# Training using Achalasia - Copy (2).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (2).yml
# Training using data226.yml
# List Trainer: [####################] 100%
# Training completed for data226.yml
# Training using data89.yml
# List Trainer: [####################] 100%
# Training completed for data89.yml
# Training using data232.yml
# List Trainer: [####################] 100%
# Training completed for data232.yml
# Training using data62.yml
# List Trainer: [####################] 100%
# Training completed for data62.yml
# Training using data76.yml
# List Trainer: [####################] 100%
# Training completed for data76.yml
# Training using Binge drinking.yml
# List Trainer: [####################] 100%
# Training completed for Binge drinking.yml
# Training using Achalasia - Copy (13).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (13).yml
# Training using doctor.yml
# List Trainer: [####################] 100%
# Training completed for doctor.yml
# Training using p8.yml
# List Trainer: [####################] 100%
# Training completed for p8.yml
# Training using Amyloidosis.yml
# List Trainer: [####################] 100%
# Training completed for Amyloidosis.yml
# Training using data77.yml
# List Trainer: [####################] 100%
# Training completed for data77.yml
# Training using data63.yml
# List Trainer: [####################] 100%
# Training completed for data63.yml
# Training using data233.yml
# List Trainer: [####################] 100%
# Training completed for data233.yml
# Training using data88.yml
# List Trainer: [####################] 100%
# Training completed for data88.yml
# Training using data227.yml
# List Trainer: [####################] 100%
# Training completed for data227.yml
# Training using Achalasia - Copy - Copy (10).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (10).yml
# Training using disease_X.yml
# List Trainer: [####################] 100%
# Training completed for disease_X.yml
# Training using data186.yml
# List Trainer: [####################] 100%
# Training completed for data186.yml
# Training using data192.yml
# List Trainer: [####################] 100%
# Training completed for data192.yml
# Training using data145.yml
# List Trainer: [####################] 100%
# Training completed for data145.yml
# Training using data151.yml
# List Trainer: [####################] 100%
# Training completed for data151.yml
# Training using Achalasia - Copy (29).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (29).yml
# Training using data179.yml
# List Trainer: [####################] 100%
# Training completed for data179.yml
# Training using data155.yml
# List Trainer: [####################] 100%
# Training completed for data155.yml
# Training using Achalasia - Copy (28).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (28).yml
# Training using data141.yml
# List Trainer: [####################] 100%
# Training completed for data141.yml
# Training using data169.yml
# List Trainer: [####################] 100%
# Training completed for data169.yml
# Training using data196.yml
# List Trainer: [####################] 100%
# Training completed for data196.yml
# Training using data182.yml
# List Trainer: [####################] 100%
# Training completed for data182.yml
# Training using Anal fissure.yml
# List Trainer: [####################] 100%
# Training completed for Anal fissure.yml
# Training using Achalasia - Copy - Copy (11).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (11).yml
# Training using data223.yml
# List Trainer: [####################] 100%
# Training completed for data223.yml
# Training using data98.yml
# List Trainer: [####################] 100%
# Training completed for data98.yml
# Training using data237.yml
# List Trainer: [####################] 100%
# Training completed for data237.yml
# Training using data67.yml
# List Trainer: [####################] 100%
# Training completed for data67.yml
# Training using data73.yml
# List Trainer: [####################] 100%
# Training completed for data73.yml
# Training using Attention-deficithyperactivity disorder in children.yml
# List Trainer: [####################] 100%
# Training completed for Attention-deficithyperactivity disorder in children.yml
# Training using data72.yml
# List Trainer: [####################] 100%
# Training completed for data72.yml
# Training using data66.yml
# List Trainer: [####################] 100%
# Training completed for data66.yml
# Training using Appendicitis.yml
# List Trainer: [####################] 100%
# Training completed for Appendicitis.yml
# Training using Acute coronary syndrome.yml
# List Trainer: [####################] 100%
# Training completed for Acute coronary syndrome.yml
# Training using Achalasia - Copy (12).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (12).yml
# Training using data236.yml
# List Trainer: [####################] 100%
# Training completed for data236.yml
# Training using data99.yml
# List Trainer: [####################] 100%
# Training completed for data99.yml
# Training using data222.yml
# List Trainer: [####################] 100%
# Training completed for data222.yml
# Training using Achalasia - Copy (3).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (3).yml
# Training using data183.yml
# List Trainer: [####################] 100%
# Training completed for data183.yml
# Training using data197.yml
# List Trainer: [####################] 100%
# Training completed for data197.yml
# Training using data168.yml
# List Trainer: [####################] 100%
# Training completed for data168.yml
# Training using data140.yml
# List Trainer: [####################] 100%
# Training completed for data140.yml
# Training using Anorgasmia in women.yml
# List Trainer: [####################] 100%
# Training completed for Anorgasmia in women.yml
# Training using data154.yml
# List Trainer: [####################] 100%
# Training completed for data154.yml
# Training using Carotid artery disease.yml
# List Trainer: [####################] 100%
# Training completed for Carotid artery disease.yml
# Training using data142.yml
# List Trainer: [####################] 100%
# Training completed for data142.yml
# Training using data156.yml
# List Trainer: [####################] 100%
# Training completed for data156.yml
# Training using data181.yml
# List Trainer: [####################] 100%
# Training completed for data181.yml
# Training using Achalasia - Copy (24).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (24).yml
# Training using data195.yml
# List Trainer: [####################] 100%
# Training completed for data195.yml
# Training using data234.yml
# List Trainer: [####################] 100%
# Training completed for data234.yml
# Training using data220.yml
# List Trainer: [####################] 100%
# Training completed for data220.yml
# Training using data208.yml
# List Trainer: [####################] 100%
# Training completed for data208.yml
# Training using data58.yml
# List Trainer: [####################] 100%
# Training completed for data58.yml
# Training using data70.yml
# List Trainer: [####################] 100%
# Training completed for data70.yml
# Training using data64.yml
# List Trainer: [####################] 100%
# Training completed for data64.yml
# Training using Amniotic fluid embolism.yml
# List Trainer: [####################] 100%
# Training completed for Amniotic fluid embolism.yml
# Training using greetings.yml
# List Trainer: [####################] 100%
# Training completed for greetings.yml
# Training using Alcohol use disorder.yml
# List Trainer: [####################] 100%
# Training completed for Alcohol use disorder.yml
# Training using Carbuncles and boils.yml
# List Trainer: [####################] 100%
# Training completed for Carbuncles and boils.yml
# Training using Achalasia - Copy - Copy (27).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (27).yml
# Training using Brain AVM.yml
# List Trainer: [####################] 100%
# Training completed for Brain AVM.yml
# Training using data65.yml
# List Trainer: [####################] 100%
# Training completed for data65.yml
# Training using data71.yml
# List Trainer: [####################] 100%
# Training completed for data71.yml
# Training using generalhealth.yml
# List Trainer: [####################] 100%
# Training completed for generalhealth.yml
# Training using Behcet_s disease.yml
# List Trainer: [####################] 100%
# Training completed for Behcet_s disease.yml
# Training using data59.yml
# List Trainer: [####################] 100%
# Training completed for data59.yml
# Training using data209.yml
# List Trainer: [####################] 100%
# Training completed for data209.yml
# Training using data221.yml
# List Trainer: [####################] 100%
# Training completed for data221.yml
# Training using data235.yml
# List Trainer: [####################] 100%
# Training completed for data235.yml
# Training using E. coli.yml
# List Trainer: [####################] 100%
# Training completed for E. coli.yml
# Training using Adrenal cancer.yml
# List Trainer: [####################] 100%
# Training completed for Adrenal cancer.yml
# Training using data194.yml
# List Trainer: [####################] 100%
# Training completed for data194.yml
# Training using data180.yml
# List Trainer: [####################] 100%
# Training completed for data180.yml
# Training using data157.yml
# List Trainer: [####################] 100%
# Training completed for data157.yml
# Training using data143.yml
# List Trainer: [####################] 100%
# Training completed for data143.yml
# Training using Achalasia - Copy - Copy (31).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (31).yml
# Training using data118.yml
# List Trainer: [####################] 100%
# Training completed for data118.yml
# Training using data124.yml
# List Trainer: [####################] 100%
# Training completed for data124.yml
# Training using data130.yml
# List Trainer: [####################] 100%
# Training completed for data130.yml
# Training using Achalasia - Copy (4).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (4).yml
# Training using Breast cysts.yml
# List Trainer: [####################] 100%
# Training completed for Breast cysts.yml
# Training using data252.yml
# List Trainer: [####################] 100%
# Training completed for data252.yml
# Training using data246.yml
# List Trainer: [####################] 100%
# Training completed for data246.yml
# Training using data16.yml
# List Trainer: [####################] 100%
# Training completed for data16.yml
# Training using Achalasia - Copy (15).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (15).yml
# Training using data285.yml
# List Trainer: [####################] 100%
# Training completed for data285.yml
# Training using Alpha-gal syndrome.yml
# List Trainer: [####################] 100%
# Training completed for Alpha-gal syndrome.yml
# Training using Chlamydia trachomatis.yml
# List Trainer: [####################] 100%
# Training completed for Chlamydia trachomatis.yml
# Training using Baby acne.yml
# List Trainer: [####################] 100%
# Training completed for Baby acne.yml
# Training using data284.yml
# List Trainer: [####################] 100%
# Training completed for data284.yml
# Training using data17.yml
# List Trainer: [####################] 100%
# Training completed for data17.yml
# Training using Achalasia - Copy - Copy (7).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (7).yml
# Training using data247.yml
# List Trainer: [####################] 100%
# Training completed for data247.yml
# Training using data253.yml
# List Trainer: [####################] 100%
# Training completed for data253.yml
# Training using Aplastic anemia.yml
# List Trainer: [####################] 100%
# Training completed for Aplastic anemia.yml
# Training using ARDS.yml
# List Trainer: [####################] 100%
# Training completed for ARDS.yml
# Training using Bronchitis.yml
# List Trainer: [####################] 100%
# Training completed for Bronchitis.yml
# Training using Achalasia - Copy - Copy (16).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (16).yml
# Training using Aortic valve disease.yml
# List Trainer: [####################] 100%
# Training completed for Aortic valve disease.yml
# Training using data131.yml
# List Trainer: [####################] 100%
# Training completed for data131.yml
# Training using data125.yml
# List Trainer: [####################] 100%
# Training completed for data125.yml
# Training using data133.yml
# List Trainer: [####################] 100%
# Training completed for data133.yml
# Training using data127.yml
# List Trainer: [####################] 100%
# Training completed for data127.yml
# Training using Atypical hyperplasia of the breast.yml
# List Trainer: [####################] 100%
# Training completed for Atypical hyperplasia of the breast.yml
# Training using Atypical depression.yml
# List Trainer: [####################] 100%
# Training completed for Atypical depression.yml
# Training using fever.yml
# List Trainer: [####################] 100%
# Training completed for fever.yml
# Training using Achalasia - Copy (8).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (8).yml
# Training using data279.yml
# List Trainer: [####################] 100%
# Training completed for data279.yml
# Training using data245.yml
# List Trainer: [####################] 100%
# Training completed for data245.yml
# Training using Carcinoid tumors.yml
# List Trainer: [####################] 100%
# Training completed for Carcinoid tumors.yml
# Training using Achalasia - Copy (19).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (19).yml
# Training using data251.yml
# List Trainer: [####################] 100%
# Training completed for data251.yml
# Training using data15.yml
# List Trainer: [####################] 100%
# Training completed for data15.yml
# Training using data286.yml
# List Trainer: [####################] 100%
# Training completed for data286.yml
# Training using data29.yml
# List Trainer: [####################] 100%
# Training completed for data29.yml
# Training using Achalasia - Copy - Copy (20).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (20).yml
# Training using Calciphylaxis.yml
# List Trainer: [####################] 100%
# Training completed for Calciphylaxis.yml
# Training using Antiphospholipid syndrome.yml
# List Trainer: [####################] 100%
# Training completed for Antiphospholipid syndrome.yml
# Training using A2.yml
# List Trainer: [####################] 100%
# Training completed for A2.yml
# Training using data28.yml
# List Trainer: [####################] 100%
# Training completed for data28.yml
# Training using data287.yml
# List Trainer: [####################] 100%
# Training completed for data287.yml
# Training using data14.yml
# List Trainer: [####################] 100%
# Training completed for data14.yml
# Training using data250.yml
# List Trainer: [####################] 100%
# Training completed for data250.yml
# Training using data244.yml
# List Trainer: [####################] 100%
# Training completed for data244.yml
# Training using Cervicitis.yml
# List Trainer: [####################] 100%
# Training completed for Cervicitis.yml
# Training using data278.yml
# List Trainer: [####################] 100%
# Training completed for data278.yml
# Training using Bundle branch block.yml
# List Trainer: [####################] 100%
# Training completed for Bundle branch block.yml
# Training using Achalasia - Copy (23).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (23).yml
# Training using data126.yml
# List Trainer: [####################] 100%
# Training completed for data126.yml
# Training using data132.yml
# List Trainer: [####################] 100%
# Training completed for data132.yml
# Training using data136.yml
# List Trainer: [####################] 100%
# Training completed for data136.yml
# Training using data122.yml
# List Trainer: [####################] 100%
# Training completed for data122.yml
# Training using Adenomyosis.yml
# List Trainer: [####################] 100%
# Training completed for Adenomyosis.yml
# Training using Achalasia - Copy (22).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (22).yml
# Training using Bronchiolitis.yml
# List Trainer: [####################] 100%
# Training completed for Bronchiolitis.yml
# Training using Anaphylaxis.yml
# List Trainer: [####################] 100%
# Training completed for Anaphylaxis.yml
# Training using data240.yml
# List Trainer: [####################] 100%
# Training completed for data240.yml
# Training using data254.yml
# List Trainer: [####################] 100%
# Training completed for data254.yml
# Training using data268.yml
# List Trainer: [####################] 100%
# Training completed for data268.yml
# Training using data283.yml
# List Trainer: [####################] 100%
# Training completed for data283.yml
# Training using data38.yml
# List Trainer: [####################] 100%
# Training completed for data38.yml
# Training using data10.yml
# List Trainer: [####################] 100%
# Training completed for data10.yml
# Training using Carbon monoxide poisoning.yml
# List Trainer: [####################] 100%
# Training completed for Carbon monoxide poisoning.yml
# Training using Bullous pemphigoid.yml
# List Trainer: [####################] 100%
# Training completed for Bullous pemphigoid.yml
# Training using Achalasia - Copy - Copy (21).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (21).yml
# Training using data11.yml
# List Trainer: [####################] 100%
# Training completed for data11.yml
# Training using data39.yml
# List Trainer: [####################] 100%
# Training completed for data39.yml
# Training using data282.yml
# List Trainer: [####################] 100%
# Training completed for data282.yml
# Training using data269.yml
# List Trainer: [####################] 100%
# Training completed for data269.yml
# Training using data255.yml
# List Trainer: [####################] 100%
# Training completed for data255.yml
# Training using data241.yml
# List Trainer: [####################] 100%
# Training completed for data241.yml
# Training using Achalasia - Copy (18).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (18).yml
# Training using Achalasia - Copy (9).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (9).yml
# Training using Attention-deficithyperactivity disorder in adults.yml
# List Trainer: [####################] 100%
# Training completed for Attention-deficithyperactivity disorder in adults.yml
# Training using data123.yml
# List Trainer: [####################] 100%
# Training completed for data123.yml
# Training using data137.yml
# List Trainer: [####################] 100%
# Training completed for data137.yml
# Training using data121.yml
# List Trainer: [####################] 100%
# Training completed for data121.yml
# Training using data135.yml
# List Trainer: [####################] 100%
# Training completed for data135.yml
# Training using data109.yml
# List Trainer: [####################] 100%
# Training completed for data109.yml
# Training using Achalasia - Copy - Copy (17).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (17).yml
# Training using Asthma attack.yml
# List Trainer: [####################] 100%
# Training completed for Asthma attack.yml
# Training using data257.yml
# List Trainer: [####################] 100%
# Training completed for data257.yml
# Training using data243.yml
# List Trainer: [####################] 100%
# Training completed for data243.yml
# Training using data280.yml
# List Trainer: [####################] 100%
# Training completed for data280.yml
# Training using data13.yml
# List Trainer: [####################] 100%
# Training completed for data13.yml
# Training using Achalasia - Copy - Copy (6).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy - Copy (6).yml
# Training using Barotrauma.yml
# List Trainer: [####################] 100%
# Training completed for Barotrauma.yml
# Training using Cardiogenic shock.yml
# List Trainer: [####################] 100%
# Training completed for Cardiogenic shock.yml
# Training using Autoimmune pancreatitis.yml
# List Trainer: [####################] 100%
# Training completed for Autoimmune pancreatitis.yml
# Training using Aphasia.yml
# List Trainer: [####################] 100%
# Training completed for Aphasia.yml
# Training using data12.yml
# List Trainer: [####################] 100%
# Training completed for data12.yml
# Training using Achalasia - Copy (14).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (14).yml
# Training using data281.yml
# List Trainer: [####################] 100%
# Training completed for data281.yml
# Training using data242.yml
# List Trainer: [####################] 100%
# Training completed for data242.yml
# Training using Common childhood Asthma.yml
# List Trainer: [####################] 100%
# Training completed for Common childhood Asthma.yml
# Training using data256.yml
# List Trainer: [####################] 100%
# Training completed for data256.yml
# Training using Achalasia - Copy (5).yml
# List Trainer: [####################] 100%
# Training completed for Achalasia - Copy (5).yml
# Training using data108.yml
# List Trainer: [####################] 100%
# Training completed for data108.yml
# Training using data134.yml
# List Trainer: [####################] 100%
# Training completed for data134.yml
# Training using data120.yml
# List Trainer: [####################] 100%
# Training completed for data120.yml
